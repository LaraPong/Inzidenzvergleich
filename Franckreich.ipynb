# %%
#Auvergne Rhone Alpes
import requests,json
url ="https://dashboardcovid.trial.opendatasoft.com/api/records/1.0/search/?dataset=indicateurs-de-suivi-de-lepidemie-de-covid-19-en-france&q=&sort=extract_date&facet=extract_date&facet=reg_name&facet=dep_name&facet=dep_area_code&refine.reg_name=Auvergne+Rh%C3%B4ne+Alpes&refine.extract_date=2021"
result = requests.get(url=url) #Anfrage absetzen
resultjson = json.loads(result.text)
newjson=resultjson['records'][0]['fields']

for key in newjson:
    print(key, ":", newjson[key])
# Out:
# reg_code : 84
# dep_name : Cantal
# sae_rate : 19.3
# sae_rate_cat : vert
# reg_name : Auvergne Rhône Alpes
# geo_point_2d : [45.0512638167, 2.6691151745]
# dep_code : 15
# extract_date : 2021-11-14
# ...

# %%
import requests,json
url ="https://dashboardcovid.trial.opendatasoft.com/api/records/1.0/search/?dataset=indicateurs-de-suivi-de-lepidemie-de-covid-19-en-france&q=&sort=extract_date&facet=extract_date&facet=reg_name&facet=dep_name&facet=dep_area_code&refine.reg_name=Corse"
result = requests.get(url=url) #Anfrage absetzen
resultjson = json.loads(result.text)
newjson=resultjson['records'][0]['fields']

for key in newjson:
    print(key, ":", newjson[key])
# Out:
# reg_code : 94
# dep_name : Corse-du-Sud
# sae_rate : 38.9
# sae_rate_cat : orange
# reg_name : Corse
# geo_point_2d : [41.8634601067, 8.98903284119]
# dep_code : 2A
# extract_date : 2021-11-14
# ...
